# %%
from retrievalnet.datasets.nclt import Nclt
from utils import plot_imgs
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
config = {
    'test_sequences': ['2012-01-08'],
    'camera': 4,
    'preprocessing': {'undistort': False},
}
nclt = Nclt(**config)
dataset = nclt.get_test_set()

# %%
plot_imgs([next(dataset)['image'] for _ in range(4)])
